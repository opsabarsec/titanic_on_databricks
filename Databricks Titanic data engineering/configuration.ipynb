# %% [markdown]
# # Data paths definition

# %%
raw_path = '/FileStore/tables/titanic_data.csv'

bronze_path = '/FileStore/tables/titanic/bronze'
silver_path = '/FileStore/tables/titanic/silver'
gold_path = '/FileStore/tables/titanic/gold'
